# %%
import pandas as pd

df1k10k=    pd.read_excel('https://drive.google.com/uc?export=download&id=1TpjmvKkZQsZzB0EpBpk-TwNVYdxxkO82',header = 0)
df10k20k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1bs5D7hUUbrPq0a5UrUQpTNKc4gfYFjRc',header = 0)
df20k30k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1NeMIv-vWhogrkD8BeLtxbqR3i8j09iZi',header = 0)
df30k40k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1wPMjeEMi61oN6n9LK6ntMsA0KqZXb5-H',header = 0)
df40k50k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1Vk_zKnUUr8CZ3utQCpdsZ7P9X8IIYPOU',header = 0)
df50k60k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1GFHQyp6MXTAQ0yEc76YytqjyjDerxtY6',header = 0)
df60k70k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1cBbYC_3vZUuCYkW9acUPc2zwNF7Y0T52',header = 0)
df70k80k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1LGlilGt63MhylzqC9b8Ix-fEO6VfLPne',header = 0)
df80k90k=   pd.read_excel('https://drive.google.com/uc?export=download&id=1R36IlBmxL6aAe--KqCwKdRX_CTQGi6E_',header = 0)
df90k100k=  pd.read_excel('https://drive.google.com/uc?export=download&id=1T7ol9gf3kTmmPYR6WSs-LjP83-Gc7V3t',header = 0)
df100k110k= pd.read_excel('https://drive.google.com/uc?export=download&id=17iKGfhxNS3LaHdUwYhJ7vFIM7hijSWvh',header = 0)
df110k120k= pd.read_excel('https://drive.google.com/uc?export=download&id=1eNSEwjckIIeWruQMPkW3RZpk7lYgHo3i',header = 0)
df120k130k= pd.read_excel('https://drive.google.com/uc?export=download&id=10LAhgUIre_RrQNGdDL3Fc5bUXhnTWCmB',header = 0)
df130k140k= pd.read_excel('https://drive.google.com/uc?export=download&id=1npm2UE5mbXkfqcALc_6npbuKz44q6QLa',header = 0)
df140k150k= pd.read_excel('https://drive.google.com/uc?export=download&id=1NGQqDA_AzstVfzVtA3ZADYe-K4DVZ0SM',header = 0)
df150k160k= pd.read_excel('https://drive.google.com/uc?export=download&id=1ZK3QfD5TGKqMGJWYnJzg9Rnf-LA4SqlB',header = 0)
#df160k170k= pd.read_excel('https://drive.google.com/uc?export=download&id=17y33yUYqtaWDfg57xFAiHpBWMgb5wb7n',header = 0)
df170k180k= pd.read_excel('https://drive.google.com/uc?export=download&id=1bs5D7hUUbrPq0a5UrUQpTNKc4gfYFjRc',header = 0)
df180k190k= pd.read_excel('https://drive.google.com/uc?export=download&id=1Sq6DqKs3VF41U3dpFfG-oLzYCUEy3pK1',header = 0)
df190k203k= pd.read_excel('https://drive.google.com/uc?export=download&id=1_rcYYMGL3eYx7IYtAMGkVYHRAaDgGi_a',header = 0)

# %%
import pandas as pd
data =[df1k10k,df10k20k,df20k30k,df30k40k,df40k50k,
df50k60k,df60k70k,df70k80k,df80k90k,df90k100k,
df100k110k,df110k120k,df120k130k,df130k140k,
df140k150k,df150k160k,df170k180k,df180k190k,df190k203k]

# %%
df1 = pd.concat(data)

# %%
df1 = df1.reset_index(drop = True)

# %%
df1
# Out:
#             id  ... en_confidence
# 0         8954  ...         60.53
# 1         4436  ...         68.31
# 2         5764  ...         41.69
# 3         1380  ...         63.83
# 4         2668  ...         52.73
# ...        ...  ...           ...
# 128509  203532  ...         60.19
# 128510  203533  ...         47.08
# 128511  203534  ...         64.84
# 128512  203535  ...         55.45
# 128513  203536  ...         59.22
#
# [128514 rows x 6 columns]

# %%
df1.groupby('target').describe()
# Out:
#                  id                              ... en_confidence
#               count           mean          std  ...           50%     75%       max
# target                                           ...
# Adult       12212.0    8398.369227  4220.718824  ...        62.220  68.860  78900.00
# Arts        10604.0   20178.316201  4183.839960  ...        58.115  65.170  22700.00
# Business    11262.0   34853.189398  4064.323611  ...        63.195  69.230  42733.33
# Computers    9891.0   48928.166010  3986.666364  ...        59.240  66.025  36800.00
# Games        8821.0   62654.825983  4019.433150  ...        60.470  66.670  10300.00
# Health       9993.0   76674.363855  4005.282285  ...        65.360  70.480  11300.00
# Home         9479.0   90890.731617  4117.159280  ...        66.820  70.770   2538.46
# Kids         8716.0  104983.590179  4108.575171  ...        55.720  66.670  58700.00
# News         5890.0  115875.747538  2220.169272  ...        61.600  67.480  31600.00
# ...

# %%
df = df1

# %%
from ast import literal_eval
df.loc[:,'tokens_en'] = df.loc[:,'tokens_en'].apply(lambda x: literal_eval(x))

# %%
df[df['target'] == 'Adult']['tokens_en'][0]
# Out:
# ['shop',
#  'premium',
#  'domain',
#  'security',
#  'check',
#  'sale',
#  'enter',
#  'character',
#  'continue',
#  'type',
#  'character',
#  'see',
#  'picture',
#  'view',
#  'price',
#  'web',
#  'bot',
#  'type',
#  'form',
#  'help',
#  'u',
#  'determine',
#  'human']

# %%
import nltk
nltk.download("popular")
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
top = 2500
words_frequency = {}
for category in set(df['target'].values):
        print(category)
        all_words = []
        for row in df[df['target'] == category]['tokens_en']:
            for word in row:
                all_words.append(word)
        most_common = nltk.FreqDist(w for w in all_words).most_common(top)
        words_frequency[category] = most_common
# Extract only words
for category in set(df['target'].values):
        words_frequency[category] = [word for word, number in words_frequency[category]]
# Out:
# Kids
# Reference
# Recreation
# Sports
# Society
# Health
# Home
# Adult
# News
# Science
# Computers
# Games
# Business
# Arts

# %%
from collections import Counter
words = []
for category in words_frequency.keys():
    words.extend(words_frequency[category][0:15])
words_counter = Counter(words)
words_filter = {x : words_counter[x] for x in words_counter if words_counter[x] >= 7}
words_stop = list(words_filter.keys())
for category in words_frequency.keys():
    words_frequency[category] = [word for word in words_frequency[category] if word not in words_stop]

# %%
words_filter
# Out:
# {'new': 13, 'news': 9, 'site': 7, 'u': 13}

# %%
words_frequency
# Out:
# {'Adult': ['escort',
#   'sex',
#   'domain',
#   'adult',
#   'video',
#   'girl',
#   'free',
#   'show',
#   'view',
#   'get',
#   'party',
#   'group',
#   'material',
#   'service',
#   'special',
#   'ad',
#   'one',
#   'time',
#   'contact',
#   'woman',
#   'best',
#   'year',
#   'chat',
#   'toy',
#   'like',
#   'see',
#   'right',
#   'may',
#   'gay',
#   'help',
#   'find',
#   'please',
#   'age',
#   'use',
#   'make',
#   'sexy',
#   'love',
#   'price',
#   'page',
#   'big',
#   'link',
#   'member',
#   'men',
#   'review',
#   'hot',
#   'home',
#   'anal',
#   'cock',
#   'model',
#   'post',
#   'fetish',
#   'content',
#   'web',
#   'read',
#   'community',
#   'day',
#   'name',
#   'live',
#   'also',
#   'enter',
#   'want',
#   'search',
#   'story',
#   'add',
#   'sale',
#   'information',
#   'movie',
#   'first',
#   'click',
#   'full',
#   'picture',
#   'term',
#   'male',
#   'massage',
#   'need',
#   'body',
#   'teen',
#   'know',
# ...

# %%
from collections import Counter
import numpy as np
features = np.zeros(df.shape[0] * top).reshape(df.shape[0], top)
labels = np.zeros(df.shape[0])
counter = 0
for i, row in df.iterrows():
        c = [word for word, word_count in Counter(row['tokens_en']).most_common(top)]
        labels[counter] = list(set(df['target'].values)).index(row['target'])
        for word in c:
            if word in words_frequency[row['target']]:
                features[counter][words_frequency[row['target']].index(word)] = 1
        counter += 1

# %%
from sklearn.metrics import accuracy_score
from scipy.sparse import coo_matrix
X_sparse = coo_matrix(features)

from sklearn.utils import shuffle
X, X_sparse, y = shuffle(features, X_sparse, labels, random_state=0)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr_predictions = lr.predict(X_test)
score = lr.score(X_test, y_test)
print('LogisticRegression')
print('Accuracy: ', score)
print('Top: ', top)
print('Dataset length: ', df.shape[0])
print()
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
predictions = dtc.predict(X_test)
score = dtc.score(X_test, y_test)
print('DecisionTreeClassifier')
print('Accuracy: ', score)
print('Top: ', top)
print('Dataset length: ', df.shape[0])
print()
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(X_train, y_train) 
predictions = clf.predict(X_test)
score = clf.score(X_test, y_test)
print('SVM')
print('Accuracy: ', score)
print('Top: ', top)
print('Dataset length: ', df.shape[0])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression
# Accuracy:  0.8198302287196416
# Top:  2500
# Dataset length:  128514
#
# DecisionTreeClassifier
# Accuracy:  0.630865361942938
# Top:  2500
# Dataset length:  128514
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# SVM
# Accuracy:  0.8120726243810422
# Top:  2500
# Dataset length:  128514

# %%
accuracy = accuracy_score(y_test, lr_predictions)
print('LogisticRegression')
print('Accuracy: ', accuracy)
print('Top: ', top)
# Out:
# LogisticRegression
# Accuracy:  0.8198302287196416
# Top:  2500

# %%
from sklearn.metrics import confusion_matrix,classification_report

print(confusion_matrix(y_test,lr_predictions))
print('\n')
print(classification_report(y_test,lr_predictions,target_names=set(df['target'].values)))
# Out:
# [[2489    8   25   16   20   27   19   67   10   13   38   43   49   51]
#  [  27 2448   40   21   31   29   25   88   27   48   60   49  109   82]
#  [  55   38 2566   25   26   38   29   95   16   51   52   67   92  106]
#  [  17   20   43 2285   16   18    8   46    8   27   34   20   42   51]
#  [  30   33   59   23 1583   40   21   71   22   34   62   34   52   69]
#  [  26   16   45   23   33 2812   14   60   22   24   51   41   61   80]
#  [  22   30   22   11   12   10 2821   43   16   14   22   35   33   38]
#  [  25   21   58   22   13   23    8 3561   24   26   29   25   70   65]
#  [  21   52   36   18   33   26   11   50 1379   47   38   25   48   89]
#  [  25   25   63   22   19   32   19   57   18 2096   71   38   54   85]
#  [  42   69   91   47   51   52   35   73   43   62 2477   66   81  112]
#  [  39   51   67   22   27   34   32   90   19   53   41 2310   62   96]
#  [  38   48   98   29   47   31   28  114   22   50   78   59 2920   94]
# ...

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = confusion_matrix(y_test,lr_predictions)
df_cm = pd.DataFrame(array, index = set(df['target'].values),
                  columns = set(df['target'].values))
plt.figure(figsize = (10,10))
sn.heatmap(df_cm, annot=True)

# %%
df_cm
# Out:
#             Kids  Reference  Recreation  ...  Games  Business  Arts
# Kids        2489          8          25  ...     43        49    51
# Reference     27       2448          40  ...     49       109    82
# Recreation    55         38        2566  ...     67        92   106
# Sports        17         20          43  ...     20        42    51
# Society       30         33          59  ...     34        52    69
# Health        26         16          45  ...     41        61    80
# Home          22         30          22  ...     35        33    38
# Adult         25         21          58  ...     25        70    65
# News          21         52          36  ...     25        48    89
# Science       25         25          63  ...     38        54    85
# Computers     42         69          91  ...     66        81   112
# Games         39         51          67  ...   2310        62    96
# Business      38         48          98  ...     59      2920    94
# ...

# %%
# 1. import
from sklearn.naive_bayes import MultinomialNB

# 2. instantiate a Multinomial Naive Bayes model
nb = MultinomialNB()
nb.fit(X_train, y_train) 
predictions = nb.predict(X_test)
score = nb.score(X_test, y_test)
print('Naive Bayes')
print('Score: ', score)
print('Top: ', top)

# %%
from sklearn.naive_bayes import BernoulliNB
nb = BernoulliNB()
nb.fit(X_train, y_train) 
predictions = nb.predict(X_test)
score = nb.score(X_test, y_test)
print('Naive Bayes')
print('Score: ', score)
print('Top: ', top)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
prediction = cross_val_predict(lr, features, labels, cv=5)
print(prediction)

# %%
accuracy = accuracy_score(y_test, prediction)
print (accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2ce566021681> in <module>()
# ----> 1 accuracy = accuracy_score(y_test, prediction)
#       2 print (accuracy)
#
# NameError: name 'prediction' is not defined
